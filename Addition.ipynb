# %%
from keras.models import Sequential
from keras import layers
import numpy as np
from six.moves import range
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Parameters Config

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
DIGITS = 3
if DIGITS < 3:
    TRAINING_SIZE = 8000
    Train_num = 2000
elif DIGITS == 3:
    TRAINING_SIZE = 400000
    Train_num = 100000
else:
    TRAINING_SIZE = 80000
    Train_num = 40000

REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
Add_data = False
Sub_data = False
Mul_data = True
if Mul_data :
    Train_num *= 3
if Add_data and Sub_data:
    chars = '0123456789+- '
elif Add_data :
    chars = '0123456789+ '
elif Mul_data:
    chars = '0123456789* '
else:
    chars = '0123456789- '

RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    def encode(self, C, num_rows):
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %%
ctable.indices_char
# Out:
# {0: ' ',
#  1: '*',
#  2: '0',
#  3: '1',
#  4: '2',
#  5: '3',
#  6: '4',
#  7: '5',
#  8: '6',
#  9: '7',
#  10: '8',
#  11: '9'}

# %% [markdown]
# # Data Generation

# %%
questions = []
expected = []
seen = set()
print('Generating data...')
while len(questions) < TRAINING_SIZE:
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    if Add_data and Sub_data:
        r = np.random.randint(2,size = 1)
        if r == 0:
            key = tuple(sorted([0, a, b], reverse = True))
            q = '{}+{}'.format(key[0], key[1])
            ans = str(key[0] + key[1])
        else:
            key = tuple(sorted([-1, a, b], reverse = True))
            q = '{}-{}'.format(key[0], key[1])
            ans = str(key[0] - key[1])
        if key in seen:
            continue
        seen.add(key)
        ans += ' ' * (DIGITS + 1 - len(ans))
    elif Add_data :
        key = tuple(sorted([0, a, b], reverse = True))
        q = '{}+{}'.format(key[0], key[1])
        ans = str(key[0] + key[1])
        ans += ' ' * (DIGITS + 1 - len(ans))
        if key in seen:
            continue
        seen.add(key)
    elif Mul_data :
        key = tuple(sorted([0, a, b], reverse = True))
        q = '{}*{}'.format(key[0], key[1])
        ans = str(key[0] * key[1])
        ans += ' ' * (2 * DIGITS - len(ans))
        if key in seen:
            continue
        seen.add(key)
    else:
        key = tuple(sorted([0, a, b], reverse = True))
        q = '{}-{}'.format(key[0], key[1])
        ans = str(key[0] - key[1])
        ans += ' ' * (DIGITS + 1 - len(ans))
        if key in seen:
            continue
        seen.add(key)

    query = q + ' ' * (MAXLEN - len(q))
    if REVERSE:
        query = query[::-1]
    questions.append(query)
    expected.append(ans)
print('Total addition questions:', len(questions))
# Out:
# Generating data...
# Total addition questions: 400000

# %%
print(questions[:5], expected[:5])
# Out:
# ['90*3   ', '989*9  ', '980*4  ', '210*0  ', '92*20  '] ['270   ', '8901  ', '3920  ', '0     ', '1840  ']

# %% [markdown]
# # Processing

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
if Mul_data:
    y = np.zeros((len(expected), 2 * DIGITS, len(chars)), dtype=np.bool)
else:
    y = np.zeros((len(expected), DIGITS + 1, len(chars)), dtype=np.bool)
for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(expected):
    if Mul_data:
        y[i] = ctable.encode(sentence, 2 * DIGITS)
    else:
        y[i] = ctable.encode(sentence, DIGITS + 1)
# Out:
# Vectorization...

# %%
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# train_test_split
train_x = x[:Train_num]
train_y = y[:Train_num]
test_x = x[Train_num:]
test_y = y[Train_num:]

split_at = len(train_x) - len(train_x) // 10
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (270000, 7, 12)
# (270000, 6, 12)
# Validation Data:
# (30000, 7, 12)
# (30000, 6, 12)
# Testing Data:
# (100000, 7, 12)
# (100000, 6, 12)

# %%
print("input: ", x_train[:3], '\n\n', "label: ", y_train[:3])
# Out:
# input:  [[[False False False False False False False False False  True False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False False False False False False False False False False False
#     True]]
#
#  [[False False False False False False False False False False False
#     True]
#   [False False False  True False False False False False False False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False False  True
#    False]]
#
#  [[False False False False False False False False False False  True
#    False]
#   [False False  True False False False False False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False  True False False False False False False False False
#    False]]]
#
#  label:  [[[False False False False False  True False False False False False
#    False]
#   [False False  True False False False False False False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False False False False False  True False False False False
#    False]]
#
#  [[False False False False False  True False False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False False False  True False False False False
#    False]]
#
#  [[False False False False False  True False False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False False False False False False False False False  True
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [False False False False False False False False  True False False
#    False]
#   [False False  True False False False False False False False False
#    False]]]

# %% [markdown]
# # Build Model

# %%
print('Build model...')

############################################
##### Build your own model here ############
############################################
from keras.layers import Dense, Bidirectional, Lambda, RepeatVector, TimeDistributed

model = Sequential()
model.add(Bidirectional(RNN(units = HIDDEN_SIZE*2), input_shape = (x_train.shape[1], x_train.shape[2])))
model.add(RepeatVector(y_train.shape[1]))
model.add(RNN(units = HIDDEN_SIZE*4, return_sequences = True))
model.add(TimeDistributed(Dense(units = y_train.shape[2], activation = 'softmax')))
model.add(Lambda(lambda x: x[:,::-1,:]))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 512)               550912
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 6, 512)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 6, 512)            2099200
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 6, 12)             6156
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 6, 12)             0
# =================================================================
# Total params: 2,656,268
# Trainable params: 2,656,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
it = [10,20,50,75,100]
for iteration in range(100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
    if (iteration+1) in it:
        acc = 0.0
        pre_y = model.predict(test_x)
        pre_y = np.argmax(pre_y,axis = 2)
        for i in range(test_x.shape[0]):
            rowx, rowy = test_x, test_y
            q = ctable.decode(rowx[i])
            correct = ctable.decode(rowy[i])
            guess = ctable.decode(pre_y[i], calc_argmax=False)
            if correct == guess:
                acc = acc + 1.0
        print('accuracy = ',int(acc), "/", test_x.shape[0], "   ", (acc*100.0/test_x.shape[0]) )
# Out:
# --------------------------------------------------
# Iteration 0
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 44s 163us/step - loss: 1.5907 - acc: 0.3757 - val_loss: 1.3059 - val_acc: 0.4950
# Q 676*393 T 265668 ☒ 251288
# Q 305*12  T 3660   ☒ 3500
# Q 825*76  T 62700  ☒ 64450
# Q 899*412 T 370388 ☒ 374168
# Q 903*774 T 698922 ☒ 711122
# Q 460*16  T 7360   ☒ 7140
# Q 760*62  T 47120  ☒ 40120
# Q 657*514 T 337698 ☒ 334568
# Q 861*409 T 352149 ☒ 363549
# Q 785*293 T 230005 ☒ 234105
#
# --------------------------------------------------
# Iteration 1
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 43s 160us/step - loss: 1.0825 - acc: 0.5706 - val_loss: 0.9533 - val_acc: 0.6133
# Q 605*547 T 330935 ☒ 334785
# Q 783*218 T 170694 ☒ 177734
# Q 404*344 T 138976 ☒ 147476
# Q 939*441 T 414099 ☒ 405079
# Q 915*760 T 695400 ☒ 697400
# Q 254*55  T 13970  ☒ 14770
# Q 461*276 T 127236 ☒ 127796
# Q 819*64  T 52416  ☒ 52136
# Q 801*246 T 197046 ☒ 195786
# Q 588*76  T 44688  ☒ 44448
#
# --------------------------------------------------
# Iteration 2
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 43s 159us/step - loss: 0.9185 - acc: 0.6256 - val_loss: 0.8888 - val_acc: 0.6361
# Q 617*488 T 301096 ☒ 290076
# Q 554*217 T 120218 ☒ 124218
# Q 563*409 T 230267 ☒ 232207
# Q 859*579 T 497361 ☒ 401581
# Q 365*45  T 16425  ☑ 16425
# Q 608*480 T 291840 ☒ 283240
# Q 911*54  T 49194  ☒ 49134
# Q 621*157 T 97497  ☒ 94077
# Q 474*321 T 152154 ☒ 151214
# Q 321*206 T 66126  ☒ 67866
#
# --------------------------------------------------
# Iteration 3
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 44s 162us/step - loss: 0.8676 - acc: 0.6480 - val_loss: 0.8763 - val_acc: 0.6450
# Q 682*423 T 288486 ☒ 296706
# Q 779*291 T 226689 ☒ 232789
# Q 282*144 T 40608  ☒ 44208
# Q 600*320 T 192000 ☑ 192000
# Q 431*177 T 76287  ☒ 76247
# Q 800*247 T 197600 ☒ 205600
# Q 666*492 T 327672 ☒ 326792
# Q 629*333 T 209457 ☒ 202777
# Q 752*442 T 332384 ☒ 334764
# Q 558*243 T 135594 ☒ 135574
#
# --------------------------------------------------
# Iteration 4
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 45s 167us/step - loss: 0.8165 - acc: 0.6738 - val_loss: 0.7952 - val_acc: 0.6825
# Q 670*23  T 15410  ☑ 15410
# Q 894*91  T 81354  ☒ 81654
# Q 174*171 T 29754  ☒ 26294
# Q 829*422 T 349838 ☒ 349518
# Q 824*685 T 564440 ☒ 569940
# Q 354*39  T 13806  ☒ 13926
# Q 915*148 T 135420 ☒ 133120
# Q 773*102 T 78846  ☑ 78846
# Q 318*76  T 24168  ☒ 24688
# Q 225*65  T 14625  ☒ 15825
#
# --------------------------------------------------
# Iteration 5
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 172us/step - loss: 0.7545 - acc: 0.7046 - val_loss: 0.7276 - val_acc: 0.7161
# Q 521*59  T 30739  ☒ 30939
# Q 270*267 T 72090  ☒ 78490
# Q 947*19  T 17993  ☒ 17393
# Q 882*614 T 541548 ☒ 543688
# Q 628*347 T 217916 ☒ 218016
# Q 655*314 T 205670 ☒ 202470
# Q 717*29  T 20793  ☒ 20353
# Q 901*487 T 438787 ☒ 436687
# Q 763*172 T 131236 ☒ 130536
# Q 703*79  T 55537  ☒ 55317
#
# --------------------------------------------------
# Iteration 6
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 46s 170us/step - loss: 0.6730 - acc: 0.7425 - val_loss: 0.6457 - val_acc: 0.7527
# Q 886*249 T 220614 ☒ 222614
# Q 703*321 T 225663 ☒ 221863
# Q 941*597 T 561777 ☒ 565977
# Q 911*408 T 371688 ☒ 371288
# Q 683*454 T 310082 ☒ 304682
# Q 667*2   T 1334   ☑ 1334
# Q 446*70  T 31220  ☑ 31220
# Q 888*735 T 652680 ☒ 653480
# Q 269*109 T 29321  ☒ 39621
# Q 989*401 T 396589 ☒ 397689
#
# --------------------------------------------------
# Iteration 7
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 174us/step - loss: 0.5984 - acc: 0.7711 - val_loss: 0.5886 - val_acc: 0.7713
# Q 77*62   T 4774   ☒ 4894
# Q 668*68  T 45424  ☒ 45324
# Q 740*301 T 222740 ☒ 220740
# Q 371*153 T 56763  ☒ 54263
# Q 852*268 T 228336 ☒ 220736
# Q 153*42  T 6426   ☒ 6026
# Q 647*453 T 293091 ☒ 299091
# Q 432*202 T 87264  ☒ 86464
# Q 514*309 T 158826 ☒ 159726
# Q 363*107 T 38841  ☒ 38741
#
# --------------------------------------------------
# Iteration 8
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 173us/step - loss: 0.5497 - acc: 0.7873 - val_loss: 0.5874 - val_acc: 0.7717
# Q 936*79  T 73944  ☒ 74144
# Q 941*139 T 130799 ☒ 138999
# Q 930*637 T 592410 ☒ 595410
# Q 263*16  T 4208   ☒ 4108
# Q 714*301 T 214914 ☒ 214514
# Q 600*149 T 89400  ☑ 89400
# Q 736*420 T 309120 ☒ 303120
# Q 969*962 T 932178 ☒ 931878
# Q 603*191 T 115173 ☑ 115173
# Q 962*36  T 34632  ☑ 34632
#
# --------------------------------------------------
# Iteration 9
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 174us/step - loss: 0.5089 - acc: 0.8012 - val_loss: 0.5402 - val_acc: 0.7860
# Q 949*871 T 826579 ☒ 826979
# Q 790*213 T 168270 ☒ 167270
# Q 976*391 T 381616 ☒ 381816
# Q 794*345 T 273930 ☑ 273930
# Q 781*541 T 422521 ☒ 422921
# Q 361*182 T 65702  ☒ 67402
# Q 553*10  T 5530   ☑ 5530
# Q 109*62  T 6758   ☑ 6758
# Q 539*80  T 43120  ☑ 43120
# Q 361*271 T 97831  ☒ 99031
# accuracy =  18878 / 100000     18.878
#
# --------------------------------------------------
# Iteration 10
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 46s 170us/step - loss: 0.4737 - acc: 0.8138 - val_loss: 0.4956 - val_acc: 0.8023
# Q 263*45  T 11835  ☑ 11835
# Q 564*167 T 94188  ☒ 94088
# Q 608*76  T 46208  ☒ 46608
# Q 331*274 T 90694  ☒ 90794
# Q 407*304 T 123728 ☒ 123928
# Q 419*357 T 149583 ☒ 147183
# Q 325*103 T 33475  ☒ 33375
# Q 746*694 T 517724 ☒ 515324
# Q 886*273 T 241878 ☒ 242978
# Q 580*169 T 98020  ☒ 98620
#
# --------------------------------------------------
# Iteration 11
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 174us/step - loss: 0.4415 - acc: 0.8255 - val_loss: 0.4759 - val_acc: 0.8090
# Q 655*649 T 425095 ☒ 424895
# Q 736*532 T 391552 ☒ 398952
# Q 739*607 T 448573 ☒ 449673
# Q 717*357 T 255969 ☒ 256969
# Q 953*46  T 43838  ☒ 43538
# Q 721*257 T 185297 ☒ 186097
# Q 805*661 T 532105 ☒ 532905
# Q 22*7    T 154    ☑ 154
# Q 590*550 T 324500 ☒ 324400
# Q 937*656 T 614672 ☒ 614572
#
# --------------------------------------------------
# Iteration 12
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 176us/step - loss: 0.4148 - acc: 0.8351 - val_loss: 0.4593 - val_acc: 0.8144
# Q 636*551 T 350436 ☒ 348036
# Q 560*76  T 42560  ☑ 42560
# Q 988*115 T 113620 ☒ 113420
# Q 281*179 T 50299  ☒ 51099
# Q 536*194 T 103984 ☒ 104584
# Q 638*50  T 31900  ☑ 31900
# Q 492*235 T 115620 ☒ 115420
# Q 735*434 T 318990 ☒ 311490
# Q 333*186 T 61938  ☒ 61538
# Q 524*253 T 132572 ☒ 133172
#
# --------------------------------------------------
# Iteration 13
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 46s 171us/step - loss: 0.3894 - acc: 0.8444 - val_loss: 0.4479 - val_acc: 0.8194
# Q 522*201 T 104922 ☒ 104722
# Q 905*865 T 782825 ☑ 782825
# Q 770*639 T 492030 ☒ 484030
# Q 799*177 T 141423 ☒ 140023
# Q 494*395 T 195130 ☒ 195730
# Q 488*371 T 181048 ☒ 181248
# Q 771*340 T 262140 ☒ 264140
# Q 736*715 T 526240 ☒ 526640
# Q 195*87  T 16965  ☒ 16765
# Q 365*45  T 16425  ☑ 16425
#
# --------------------------------------------------
# Iteration 14
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 176us/step - loss: 0.3683 - acc: 0.8525 - val_loss: 0.4295 - val_acc: 0.8258
# Q 841*398 T 334718 ☒ 334118
# Q 760*412 T 313120 ☑ 313120
# Q 948*577 T 546996 ☒ 548596
# Q 992*139 T 137888 ☒ 137488
# Q 788*760 T 598880 ☒ 596880
# Q 80*26   T 2080   ☑ 2080
# Q 876*621 T 543996 ☒ 544196
# Q 569*488 T 277672 ☒ 278472
# Q 891*583 T 519453 ☒ 520153
# Q 294*63  T 18522  ☑ 18522
#
# --------------------------------------------------
# Iteration 15
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.3479 - acc: 0.8601 - val_loss: 0.4185 - val_acc: 0.8303
# Q 855*679 T 580545 ☒ 586345
# Q 330*64  T 21120  ☒ 19120
# Q 338*155 T 52390  ☑ 52390
# Q 467*8   T 3736   ☑ 3736
# Q 935*784 T 733040 ☒ 733840
# Q 869*777 T 675213 ☒ 671313
# Q 930*901 T 837930 ☒ 828930
# Q 578*96  T 55488  ☒ 55888
# Q 935*53  T 49555  ☒ 49655
# Q 735*307 T 225645 ☒ 225545
#
# --------------------------------------------------
# Iteration 16
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.3305 - acc: 0.8674 - val_loss: 0.4047 - val_acc: 0.8359
# Q 672*421 T 282912 ☒ 283112
# Q 654*604 T 395016 ☒ 395216
# Q 484*208 T 100672 ☒ 10051
# Q 622*413 T 256886 ☒ 256686
# Q 949*555 T 526695 ☑ 526695
# Q 770*79  T 60830  ☒ 60030
# Q 909*323 T 293607 ☒ 293307
# Q 936*862 T 806832 ☒ 806432
# Q 707*594 T 419958 ☒ 420558
# Q 642*1   T 642    ☑ 642
#
# --------------------------------------------------
# Iteration 17
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.3146 - acc: 0.8735 - val_loss: 0.3973 - val_acc: 0.8387
# Q 624*559 T 348816 ☒ 349616
# Q 963*64  T 61632  ☒ 61832
# Q 265*127 T 33655  ☒ 33755
# Q 791*581 T 459571 ☒ 459771
# Q 678*342 T 231876 ☒ 232876
# Q 817*725 T 592325 ☒ 592525
# Q 957*884 T 845988 ☒ 846988
# Q 890*189 T 168210 ☒ 169210
# Q 344*269 T 92536  ☑ 92536
# Q 788*713 T 561844 ☒ 562244
#
# --------------------------------------------------
# Iteration 18
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.2999 - acc: 0.8795 - val_loss: 0.3879 - val_acc: 0.8432
# Q 812*540 T 438480 ☒ 430480
# Q 677*299 T 202423 ☒ 202823
# Q 200*96  T 19200  ☑ 19200
# Q 962*135 T 129870 ☒ 130470
# Q 367*28  T 10276  ☒ 10476
# Q 822*0   T 0      ☑ 0
# Q 813*1   T 813    ☑ 813
# Q 688*232 T 159616 ☒ 169216
# Q 877*683 T 598991 ☒ 599391
# Q 948*383 T 363084 ☒ 363284
#
# --------------------------------------------------
# Iteration 19
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.2886 - acc: 0.8841 - val_loss: 0.3882 - val_acc: 0.8430
# Q 624*202 T 126048 ☒ 126648
# Q 989*96  T 94944  ☑ 94944
# Q 322*252 T 81144  ☒ 81344
# Q 896*80  T 71680  ☑ 71680
# Q 949*33  T 31317  ☑ 31317
# Q 685*361 T 247285 ☒ 246485
# Q 501*61  T 30561  ☑ 30561
# Q 748*273 T 204204 ☒ 204004
# Q 957*366 T 350262 ☒ 349662
# Q 665*346 T 230090 ☒ 220090
# accuracy =  32336 / 100000     32.336
#
# --------------------------------------------------
# Iteration 20
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.2755 - acc: 0.8892 - val_loss: 0.3782 - val_acc: 0.8480
# Q 993*21  T 20853  ☑ 20853
# Q 861*72  T 61992  ☒ 62192
# Q 995*924 T 919380 ☑ 919380
# Q 556*154 T 85624  ☒ 85824
# Q 220*57  T 12540  ☑ 12540
# Q 730*674 T 492020 ☒ 490020
# Q 979*815 T 797885 ☒ 798785
# Q 710*102 T 72420  ☑ 72420
# Q 507*135 T 68445  ☒ 68045
# Q 972*932 T 905904 ☒ 905104
#
# --------------------------------------------------
# Iteration 21
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.2647 - acc: 0.8937 - val_loss: 0.3792 - val_acc: 0.8487
# Q 451*424 T 191224 ☒ 189424
# Q 455*99  T 45045  ☒ 44045
# Q 760*675 T 513000 ☒ 515000
# Q 980*519 T 508620 ☒ 507620
# Q 749*381 T 285369 ☑ 285369
# Q 798*241 T 192318 ☒ 192118
# Q 731*3   T 2193   ☑ 2193
# Q 427*110 T 46970  ☑ 46970
# Q 901*88  T 79288  ☑ 79288
# Q 953*121 T 115313 ☒ 115513
#
# --------------------------------------------------
# Iteration 22
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.2571 - acc: 0.8971 - val_loss: 0.3697 - val_acc: 0.8521
# Q 960*735 T 705600 ☑ 705600
# Q 331*278 T 92018  ☒ 91218
# Q 799*598 T 477802 ☒ 478802
# Q 935*186 T 173910 ☒ 174310
# Q 862*17  T 14654  ☑ 14654
# Q 894*650 T 581100 ☑ 581100
# Q 367*269 T 98723  ☒ 98323
# Q 716*594 T 425304 ☒ 425504
# Q 889*350 T 311150 ☑ 311150
# Q 931*711 T 661941 ☒ 662141
#
# --------------------------------------------------
# Iteration 23
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.2430 - acc: 0.9029 - val_loss: 0.3919 - val_acc: 0.8471
# Q 541*499 T 269959 ☒ 270959
# Q 636*128 T 81408  ☒ 81008
# Q 992*498 T 494016 ☒ 494616
# Q 333*230 T 76590  ☑ 76590
# Q 686*458 T 314188 ☒ 314588
# Q 559*378 T 211302 ☒ 210502
# Q 549*517 T 283833 ☒ 283733
# Q 329*317 T 104293 ☒ 103593
# Q 828*487 T 403236 ☒ 404836
# Q 444*404 T 179376 ☒ 179576
#
# --------------------------------------------------
# Iteration 24
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.2354 - acc: 0.9061 - val_loss: 0.3746 - val_acc: 0.8541
# Q 751*692 T 519692 ☒ 524092
# Q 530*276 T 146280 ☑ 146280
# Q 630*442 T 278460 ☒ 288460
# Q 681*71  T 48351  ☑ 48351
# Q 143*8   T 1144   ☑ 1144
# Q 623*151 T 94073  ☒ 94573
# Q 743*334 T 248162 ☒ 247562
# Q 739*343 T 253477 ☒ 253777
# Q 840*736 T 618240 ☑ 618240
# Q 774*161 T 124614 ☒ 124414
#
# --------------------------------------------------
# Iteration 25
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.2283 - acc: 0.9090 - val_loss: 0.3815 - val_acc: 0.8522
# Q 937*61  T 57157  ☑ 57157
# Q 420*325 T 136500 ☒ 137500
# Q 847*714 T 604758 ☒ 604358
# Q 696*78  T 54288  ☑ 54288
# Q 615*591 T 363465 ☑ 363465
# Q 494*187 T 92378  ☒ 92178
# Q 976*200 T 195200 ☑ 195200
# Q 318*221 T 70278  ☒ 70478
# Q 805*673 T 541765 ☒ 541165
# Q 647*453 T 293091 ☒ 291891
#
# --------------------------------------------------
# Iteration 26
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.2190 - acc: 0.9133 - val_loss: 0.3830 - val_acc: 0.8543
# Q 761*563 T 428443 ☒ 429643
# Q 756*706 T 533736 ☒ 533936
# Q 819*644 T 527436 ☒ 527036
# Q 949*443 T 420407 ☒ 410207
# Q 962*958 T 921596 ☑ 921596
# Q 841*361 T 303601 ☒ 304901
# Q 303*92  T 27876  ☒ 27076
# Q 858*446 T 382668 ☒ 383668
# Q 912*786 T 716832 ☒ 716032
# Q 847*314 T 265958 ☒ 266358
#
# --------------------------------------------------
# Iteration 27
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 173us/step - loss: 0.2134 - acc: 0.9156 - val_loss: 0.3853 - val_acc: 0.8541
# Q 898*125 T 112250 ☑ 112250
# Q 843*204 T 171972 ☒ 171572
# Q 478*120 T 57360  ☑ 57360
# Q 884*573 T 506532 ☑ 506532
# Q 736*313 T 230368 ☒ 230568
# Q 916*286 T 261976 ☒ 261376
# Q 897*488 T 437736 ☒ 437336
# Q 463*112 T 51856  ☒ 51456
# Q 831*489 T 406359 ☒ 406159
# Q 830*112 T 92960  ☒ 93960
#
# --------------------------------------------------
# Iteration 28
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.2047 - acc: 0.9197 - val_loss: 0.3805 - val_acc: 0.8563
# Q 322*97  T 31234  ☒ 31634
# Q 875*575 T 503125 ☒ 503625
# Q 274*7   T 1918   ☑ 1918
# Q 903*722 T 651966 ☒ 652366
# Q 576*5   T 2880   ☑ 2880
# Q 718*272 T 195296 ☒ 195696
# Q 632*367 T 231944 ☒ 231344
# Q 974*311 T 302914 ☒ 303514
# Q 623*427 T 266021 ☒ 265621
# Q 967*172 T 166324 ☑ 166324
#
# --------------------------------------------------
# Iteration 29
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 176us/step - loss: 0.1991 - acc: 0.9219 - val_loss: 0.3880 - val_acc: 0.8556
# Q 901*716 T 645116 ☑ 645116
# Q 911*109 T 99299  ☑ 99299
# Q 616*87  T 53592  ☒ 53792
# Q 562*92  T 51704  ☑ 51704
# Q 512*165 T 84480  ☑ 84480
# Q 771*690 T 531990 ☒ 533990
# Q 844*712 T 600928 ☒ 601328
# Q 981*954 T 935874 ☒ 936874
# Q 955*117 T 111735 ☒ 112735
# Q 553*30  T 16590  ☑ 16590
#
# --------------------------------------------------
# Iteration 30
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 50s 185us/step - loss: 0.1914 - acc: 0.9254 - val_loss: 0.3921 - val_acc: 0.8554
# Q 531*407 T 216117 ☒ 216917
# Q 920*83  T 76360  ☑ 76360
# Q 889*832 T 739648 ☒ 739848
# Q 796*68  T 54128  ☑ 54128
# Q 858*636 T 545688 ☒ 543288
# Q 877*739 T 648103 ☒ 648703
# Q 467*21  T 9807   ☑ 9807
# Q 944*729 T 688176 ☒ 687776
# Q 905*385 T 348425 ☑ 348425
# Q 730*674 T 492020 ☑ 492020
#
# --------------------------------------------------
# Iteration 31
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.1858 - acc: 0.9277 - val_loss: 0.3951 - val_acc: 0.8559
# Q 767*643 T 493181 ☒ 493981
# Q 596*88  T 52448  ☒ 52248
# Q 827*586 T 484622 ☒ 483422
# Q 841*156 T 131196 ☒ 130596
# Q 773*286 T 221078 ☒ 220878
# Q 590*95  T 56050  ☒ 55050
# Q 878*172 T 151016 ☒ 151216
# Q 912*286 T 260832 ☒ 260232
# Q 798*293 T 233814 ☒ 234014
# Q 981*313 T 307053 ☒ 307393
#
# --------------------------------------------------
# Iteration 32
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 182us/step - loss: 0.1784 - acc: 0.9309 - val_loss: 0.4004 - val_acc: 0.8563
# Q 477*258 T 123066 ☒ 123666
# Q 395*8   T 3160   ☑ 3160
# Q 363*232 T 84216  ☒ 84616
# Q 471*305 T 143655 ☑ 143655
# Q 976*11  T 10736  ☑ 10736
# Q 926*72  T 66672  ☑ 66672
# Q 210*178 T 37380  ☑ 37380
# Q 414*155 T 64170  ☒ 64770
# Q 927*444 T 411588 ☒ 411188
# Q 951*790 T 751290 ☑ 751290
#
# --------------------------------------------------
# Iteration 33
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.1759 - acc: 0.9323 - val_loss: 0.4002 - val_acc: 0.8572
# Q 873*519 T 453087 ☒ 453787
# Q 710*567 T 402570 ☒ 401570
# Q 983*332 T 326356 ☒ 326956
# Q 547*465 T 254355 ☒ 254855
# Q 100*66  T 6600   ☑ 6600
# Q 862*592 T 510304 ☒ 510904
# Q 562*205 T 115210 ☒ 114210
# Q 678*288 T 195264 ☒ 195464
# Q 725*547 T 396575 ☑ 396575
# Q 667*184 T 122728 ☒ 122528
#
# --------------------------------------------------
# Iteration 34
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.1651 - acc: 0.9368 - val_loss: 0.4167 - val_acc: 0.8540
# Q 788*85  T 66980  ☑ 66980
# Q 600*365 T 219000 ☑ 219000
# Q 300*151 T 45300  ☑ 45300
# Q 794*218 T 173092 ☒ 172892
# Q 652*505 T 329260 ☒ 320260
# Q 377*136 T 51272  ☒ 50172
# Q 378*61  T 23058  ☒ 22658
# Q 486*194 T 94284  ☑ 94284
# Q 977*323 T 315571 ☒ 315371
# Q 559*29  T 16211  ☑ 16211
#
# --------------------------------------------------
# Iteration 35
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.1659 - acc: 0.9367 - val_loss: 0.4097 - val_acc: 0.8574
# Q 861*578 T 497658 ☒ 497458
# Q 887*474 T 420438 ☒ 420838
# Q 844*768 T 648192 ☒ 647392
# Q 861*712 T 613032 ☒ 613832
# Q 985*552 T 543720 ☑ 543720
# Q 627*224 T 140448 ☑ 140448
# Q 887*474 T 420438 ☒ 420838
# Q 143*96  T 13728  ☑ 13728
# Q 948*132 T 125136 ☑ 125136
# Q 791*201 T 158991 ☒ 159191
#
# --------------------------------------------------
# Iteration 36
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.1573 - acc: 0.9407 - val_loss: 0.4144 - val_acc: 0.8580
# Q 865*760 T 657400 ☑ 657400
# Q 709*580 T 411220 ☒ 419220
# Q 961*518 T 497798 ☒ 497998
# Q 550*216 T 118800 ☑ 118800
# Q 732*499 T 365268 ☒ 365868
# Q 494*405 T 200070 ☒ 199270
# Q 782*42  T 32844  ☑ 32844
# Q 564*468 T 263952 ☑ 263952
# Q 880*297 T 261360 ☑ 261360
# Q 708*501 T 354708 ☒ 354508
#
# --------------------------------------------------
# Iteration 37
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.1508 - acc: 0.9433 - val_loss: 0.4268 - val_acc: 0.8575
# Q 486*148 T 71928  ☒ 71328
# Q 457*341 T 155837 ☒ 156237
# Q 555*271 T 150405 ☒ 150805
# Q 907*793 T 719251 ☒ 719051
# Q 728*189 T 137592 ☒ 138192
# Q 847*58  T 49126  ☑ 49126
# Q 913*489 T 446457 ☒ 446857
# Q 589*469 T 276241 ☒ 277241
# Q 641*150 T 96150  ☑ 96150
# Q 484*43  T 20812  ☑ 20812
#
# --------------------------------------------------
# Iteration 38
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.1465 - acc: 0.9451 - val_loss: 0.4230 - val_acc: 0.8590
# Q 711*692 T 492012 ☒ 492412
# Q 521*39  T 20319  ☑ 20319
# Q 744*543 T 403992 ☒ 404792
# Q 685*543 T 371955 ☒ 371155
# Q 545*219 T 119355 ☒ 119955
# Q 303*45  T 13635  ☑ 13635
# Q 325*34  T 11050  ☑ 11050
# Q 499*66  T 32934  ☒ 32334
# Q 569*49  T 27881  ☑ 27881
# Q 919*902 T 828938 ☒ 829178
#
# --------------------------------------------------
# Iteration 39
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.1423 - acc: 0.9469 - val_loss: 0.4447 - val_acc: 0.8562
# Q 949*281 T 266669 ☒ 266269
# Q 505*93  T 46965  ☒ 46765
# Q 781*595 T 464695 ☑ 464695
# Q 626*234 T 146484 ☒ 146284
# Q 655*239 T 156545 ☒ 156345
# Q 361*75  T 27075  ☒ 27575
# Q 554*333 T 184482 ☒ 184082
# Q 969*829 T 803301 ☒ 802501
# Q 732*28  T 20496  ☑ 20496
# Q 526*108 T 56808  ☒ 57408
#
# --------------------------------------------------
# Iteration 40
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.1358 - acc: 0.9497 - val_loss: 0.4589 - val_acc: 0.8559
# Q 319*14  T 4466   ☑ 4466
# Q 838*649 T 543862 ☒ 543662
# Q 722*66  T 47652  ☑ 47652
# Q 651*450 T 292950 ☑ 292950
# Q 939*487 T 457293 ☒ 457493
# Q 169*61  T 10309  ☒ 10409
# Q 781*94  T 73414  ☒ 73814
# Q 854*782 T 667828 ☒ 678028
# Q 952*179 T 170408 ☒ 170208
# Q 498*9   T 4482   ☑ 4482
#
# --------------------------------------------------
# Iteration 41
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 176us/step - loss: 0.1339 - acc: 0.9509 - val_loss: 0.4670 - val_acc: 0.8558
# Q 300*213 T 63900  ☑ 63900
# Q 689*440 T 303160 ☒ 305160
# Q 393*192 T 75456  ☒ 75656
# Q 957*130 T 124410 ☑ 124410
# Q 951*352 T 334752 ☒ 335752
# Q 414*260 T 107640 ☑ 107640
# Q 794*42  T 33348  ☑ 33348
# Q 852*749 T 638148 ☑ 638148
# Q 859*85  T 73015  ☑ 73015
# Q 301*195 T 58695  ☒ 59695
#
# --------------------------------------------------
# Iteration 42
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.1303 - acc: 0.9523 - val_loss: 0.4560 - val_acc: 0.8582
# Q 250*39  T 9750   ☑ 9750
# Q 795*262 T 208290 ☒ 208890
# Q 739*729 T 538731 ☒ 538931
# Q 899*126 T 113274 ☒ 112274
# Q 850*142 T 120700 ☑ 120700
# Q 629*87  T 54723  ☑ 54723
# Q 754*39  T 29406  ☑ 29406
# Q 660*305 T 201300 ☒ 210300
# Q 949*475 T 450775 ☒ 451975
# Q 359*266 T 95494  ☒ 97694
#
# --------------------------------------------------
# Iteration 43
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 51s 188us/step - loss: 0.1242 - acc: 0.9550 - val_loss: 0.4751 - val_acc: 0.8559
# Q 915*736 T 673440 ☒ 673040
# Q 249*121 T 30129  ☒ 29729
# Q 625*360 T 225000 ☒ 223000
# Q 355*192 T 68160  ☒ 67760
# Q 867*3   T 2601   ☑ 2601
# Q 664*328 T 217792 ☒ 217392
# Q 608*588 T 357504 ☒ 356504
# Q 424*21  T 8904   ☑ 8904
# Q 548*188 T 103024 ☒ 102024
# Q 667*433 T 288811 ☒ 288211
#
# --------------------------------------------------
# Iteration 44
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 65s 240us/step - loss: 0.1188 - acc: 0.9571 - val_loss: 0.4806 - val_acc: 0.8564
# Q 592*592 T 350464 ☒ 340064
# Q 954*577 T 550458 ☒ 549458
# Q 861*821 T 706881 ☒ 706781
# Q 845*467 T 394615 ☒ 394215
# Q 647*267 T 172749 ☒ 173149
# Q 834*20  T 16680  ☑ 16680
# Q 672*639 T 429408 ☒ 429008
# Q 763*13  T 9919   ☒ 9911
# Q 492*135 T 66420  ☑ 66420
# Q 866*207 T 179262 ☒ 178862
#
# --------------------------------------------------
# Iteration 45
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 80s 295us/step - loss: 0.1174 - acc: 0.9580 - val_loss: 0.4917 - val_acc: 0.8559
# Q 585*479 T 280215 ☒ 280815
# Q 559*556 T 310804 ☒ 309404
# Q 943*382 T 360226 ☒ 360726
# Q 976*532 T 519232 ☒ 519832
# Q 568*508 T 288544 ☒ 288944
# Q 938*33  T 30954  ☒ 30854
# Q 842*443 T 373006 ☒ 372806
# Q 955*818 T 781190 ☒ 780190
# Q 856*98  T 83888  ☑ 83888
# Q 586*218 T 127748 ☒ 127548
#
# --------------------------------------------------
# Iteration 46
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 78s 290us/step - loss: 0.1110 - acc: 0.9606 - val_loss: 0.5133 - val_acc: 0.8531
# Q 766*227 T 173882 ☒ 174482
# Q 440*360 T 158400 ☑ 158400
# Q 895*221 T 197795 ☑ 197795
# Q 857*168 T 143976 ☒ 143576
# Q 739*265 T 195835 ☑ 195835
# Q 318*145 T 46110  ☒ 45910
# Q 335*31  T 10385  ☒ 10485
# Q 278*196 T 54488  ☒ 55684
# Q 498*84  T 41832  ☒ 41032
# Q 688*420 T 288960 ☑ 288960
#
# --------------------------------------------------
# Iteration 47
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 77s 285us/step - loss: 0.1096 - acc: 0.9612 - val_loss: 0.5032 - val_acc: 0.8560
# Q 765*259 T 198135 ☒ 198335
# Q 510*95  T 48450  ☑ 48450
# Q 533*23  T 12259  ☑ 12259
# Q 885*865 T 765525 ☑ 765525
# Q 689*390 T 268710 ☑ 268710
# Q 635*126 T 80010  ☒ 80210
# Q 650*644 T 418600 ☒ 414800
# Q 937*259 T 242683 ☒ 242283
# Q 981*421 T 413001 ☒ 413801
# Q 909*13  T 11817  ☑ 11817
#
# --------------------------------------------------
# Iteration 48
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 52s 193us/step - loss: 0.1043 - acc: 0.9635 - val_loss: 0.5059 - val_acc: 0.8575
# Q 583*321 T 187143 ☒ 187343
# Q 547*84  T 45948  ☒ 46148
# Q 501*61  T 30561  ☒ 30761
# Q 871*409 T 356239 ☒ 356439
# Q 206*199 T 40994  ☒ 41994
# Q 683*117 T 79911  ☑ 79911
# Q 781*756 T 590436 ☒ 590836
# Q 891*747 T 665577 ☑ 665577
# Q 912*301 T 274512 ☒ 275312
# Q 905*154 T 139370 ☒ 139970
#
# --------------------------------------------------
# Iteration 49
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 46s 172us/step - loss: 0.1002 - acc: 0.9651 - val_loss: 0.5281 - val_acc: 0.8553
# Q 904*403 T 364312 ☒ 364912
# Q 818*666 T 544788 ☒ 544388
# Q 866*373 T 323018 ☒ 322618
# Q 955*851 T 812705 ☒ 813705
# Q 620*317 T 196540 ☑ 196540
# Q 174*49  T 8526   ☒ 8326
# Q 877*782 T 685814 ☒ 685314
# Q 503*305 T 153415 ☒ 153115
# Q 450*27  T 12150  ☑ 12150
# Q 731*39  T 28509  ☑ 28509
# accuracy =  37144 / 100000     37.144
#
# --------------------------------------------------
# Iteration 50
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0989 - acc: 0.9656 - val_loss: 0.5327 - val_acc: 0.8557
# Q 819*791 T 647829 ☑ 647829
# Q 503*35  T 17605  ☑ 17605
# Q 376*247 T 92872  ☑ 92872
# Q 421*57  T 23997  ☒ 24597
# Q 864*125 T 108000 ☒ 107000
# Q 485*380 T 184300 ☑ 184300
# Q 505*499 T 251995 ☑ 251995
# Q 875*299 T 261625 ☑ 261625
# Q 753*561 T 422433 ☑ 422433
# Q 998*136 T 135728 ☑ 135728
#
# --------------------------------------------------
# Iteration 51
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0951 - acc: 0.9673 - val_loss: 0.5311 - val_acc: 0.8564
# Q 696*397 T 276312 ☒ 276712
# Q 921*103 T 94863  ☒ 94663
# Q 231*82  T 18942  ☒ 19142
# Q 484*139 T 67276  ☒ 67076
# Q 898*307 T 275686 ☒ 275886
# Q 813*811 T 659343 ☒ 659143
# Q 535*292 T 156220 ☒ 155620
# Q 567*94  T 53298  ☑ 53298
# Q 245*192 T 47040  ☒ 46240
# Q 635*542 T 344170 ☒ 344970
#
# --------------------------------------------------
# Iteration 52
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 174us/step - loss: 0.0935 - acc: 0.9680 - val_loss: 0.5420 - val_acc: 0.8562
# Q 926*450 T 416700 ☑ 416700
# Q 454*85  T 38590  ☑ 38590
# Q 564*477 T 269028 ☒ 269428
# Q 769*509 T 391421 ☒ 391221
# Q 805*402 T 323610 ☑ 323610
# Q 526*143 T 75218  ☒ 75418
# Q 619*60  T 37140  ☑ 37140
# Q 647*610 T 394670 ☑ 394670
# Q 540*96  T 51840  ☒ 51640
# Q 662*86  T 56932  ☒ 57032
#
# --------------------------------------------------
# Iteration 53
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 176us/step - loss: 0.0927 - acc: 0.9684 - val_loss: 0.5551 - val_acc: 0.8551
# Q 554*448 T 248192 ☒ 249592
# Q 631*611 T 385541 ☑ 385541
# Q 762*351 T 267462 ☒ 267862
# Q 336*183 T 61488  ☒ 61788
# Q 196*27  T 5292   ☒ 5092
# Q 600*85  T 51000  ☑ 51000
# Q 137*121 T 16577  ☒ 16777
# Q 840*564 T 473760 ☒ 475760
# Q 668*10  T 6680   ☑ 6680
# Q 868*507 T 440076 ☒ 449276
#
# --------------------------------------------------
# Iteration 54
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 176us/step - loss: 0.0872 - acc: 0.9707 - val_loss: 0.5610 - val_acc: 0.8552
# Q 763*112 T 85456  ☒ 85656
# Q 998*504 T 502992 ☑ 502992
# Q 839*7   T 5873   ☑ 5873
# Q 548*115 T 63020  ☒ 62020
# Q 529*8   T 4232   ☑ 4232
# Q 366*230 T 84180  ☑ 84180
# Q 515*357 T 183855 ☒ 182255
# Q 889*455 T 404495 ☒ 405495
# Q 285*262 T 74670  ☒ 74270
# Q 977*587 T 573499 ☒ 572899
#
# --------------------------------------------------
# Iteration 55
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 176us/step - loss: 0.0829 - acc: 0.9722 - val_loss: 0.5807 - val_acc: 0.8537
# Q 781*169 T 131989 ☒ 132389
# Q 647*25  T 16175  ☑ 16175
# Q 596*88  T 52448  ☒ 52248
# Q 585*16  T 9360   ☑ 9360
# Q 736*569 T 418784 ☒ 419384
# Q 746*741 T 552786 ☒ 552186
# Q 659*308 T 202972 ☒ 203772
# Q 142*32  T 4544   ☑ 4544
# Q 901*364 T 327964 ☒ 328964
# Q 833*228 T 189924 ☒ 199124
#
# --------------------------------------------------
# Iteration 56
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.0812 - acc: 0.9728 - val_loss: 0.5788 - val_acc: 0.8548
# Q 630*285 T 179550 ☑ 179550
# Q 790*18  T 14220  ☑ 14220
# Q 965*345 T 332925 ☑ 332925
# Q 897*458 T 410826 ☒ 410026
# Q 354*29  T 10266  ☑ 10266
# Q 292*178 T 51976  ☒ 52176
# Q 415*212 T 87980  ☒ 88380
# Q 801*194 T 155394 ☒ 155994
# Q 894*893 T 798342 ☒ 798542
# Q 886*671 T 594506 ☒ 594106
#
# --------------------------------------------------
# Iteration 57
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0834 - acc: 0.9721 - val_loss: 0.5820 - val_acc: 0.8548
# Q 387*309 T 119583 ☒ 110383
# Q 376*107 T 40232  ☒ 40632
# Q 796*455 T 362180 ☒ 362520
# Q 624*504 T 314496 ☑ 314496
# Q 584*235 T 137240 ☒ 137840
# Q 277*22  T 6094   ☑ 6094
# Q 185*64  T 11840  ☒ 11240
# Q 885*268 T 237180 ☑ 237180
# Q 275*11  T 3025   ☑ 3025
# Q 775*393 T 304575 ☒ 304175
#
# --------------------------------------------------
# Iteration 58
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0767 - acc: 0.9748 - val_loss: 0.5910 - val_acc: 0.8551
# Q 969*150 T 145350 ☑ 145350
# Q 982*11  T 10802  ☑ 10802
# Q 688*550 T 378400 ☑ 378400
# Q 960*59  T 56640  ☑ 56640
# Q 551*135 T 74385  ☒ 74985
# Q 671*185 T 124135 ☒ 123335
# Q 553*403 T 222859 ☒ 222659
# Q 172*132 T 22704  ☒ 23104
# Q 870*317 T 275790 ☑ 275790
# Q 561*138 T 77418  ☒ 76618
#
# --------------------------------------------------
# Iteration 59
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0746 - acc: 0.9755 - val_loss: 0.6041 - val_acc: 0.8546
# Q 604*178 T 107512 ☒ 107112
# Q 983*804 T 790332 ☑ 790332
# Q 637*347 T 221039 ☒ 220739
# Q 781*228 T 178068 ☒ 178468
# Q 370*19  T 7030   ☑ 7030
# Q 666*249 T 165834 ☒ 165434
# Q 867*714 T 619038 ☒ 618838
# Q 195*107 T 20865  ☑ 20865
# Q 877*853 T 748081 ☒ 748881
# Q 718*406 T 291508 ☒ 291108
#
# --------------------------------------------------
# Iteration 60
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0769 - acc: 0.9746 - val_loss: 0.6109 - val_acc: 0.8542
# Q 715*635 T 454025 ☒ 453025
# Q 379*354 T 134166 ☒ 133966
# Q 736*468 T 344448 ☑ 344448
# Q 293*266 T 77938  ☑ 77938
# Q 587*222 T 130314 ☒ 130114
# Q 258*231 T 59598  ☒ 59798
# Q 726*126 T 91476  ☒ 91676
# Q 604*340 T 205360 ☑ 205360
# Q 809*60  T 48540  ☑ 48540
# Q 699*105 T 73395  ☑ 73395
#
# --------------------------------------------------
# Iteration 61
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 176us/step - loss: 0.0700 - acc: 0.9773 - val_loss: 0.6174 - val_acc: 0.8541
# Q 941*879 T 827139 ☒ 827939
# Q 631*628 T 396268 ☒ 396468
# Q 290*199 T 57710  ☒ 56310
# Q 698*527 T 367846 ☒ 368646
# Q 270*2   T 540    ☑ 540
# Q 725*402 T 291450 ☑ 291450
# Q 746*629 T 469234 ☑ 469234
# Q 564*423 T 238572 ☒ 237972
# Q 463*434 T 200942 ☑ 200942
# Q 963*694 T 668322 ☑ 668322
#
# --------------------------------------------------
# Iteration 62
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0701 - acc: 0.9770 - val_loss: 0.6237 - val_acc: 0.8544
# Q 396*177 T 70092  ☒ 69492
# Q 759*199 T 151041 ☑ 151041
# Q 587*188 T 110356 ☒ 110156
# Q 796*181 T 144076 ☒ 143076
# Q 678*288 T 195264 ☒ 195064
# Q 845*533 T 450385 ☒ 450285
# Q 973*178 T 173194 ☑ 173194
# Q 954*325 T 310050 ☒ 300050
# Q 599*564 T 337836 ☒ 338236
# Q 931*12  T 11172  ☑ 11172
#
# --------------------------------------------------
# Iteration 63
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0677 - acc: 0.9781 - val_loss: 0.6298 - val_acc: 0.8551
# Q 478*230 T 109940 ☒ 111940
# Q 615*538 T 330870 ☒ 330470
# Q 862*37  T 31894  ☒ 31944
# Q 878*347 T 304666 ☑ 304666
# Q 350*314 T 109900 ☑ 109900
# Q 817*126 T 102942 ☒ 103342
# Q 610*81  T 49410  ☑ 49410
# Q 273*88  T 24024  ☒ 24224
# Q 782*518 T 405076 ☒ 405276
# Q 855*310 T 265050 ☒ 266050
#
# --------------------------------------------------
# Iteration 64
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 176us/step - loss: 0.0686 - acc: 0.9776 - val_loss: 0.6321 - val_acc: 0.8557
# Q 303*121 T 36663  ☒ 36763
# Q 992*392 T 388864 ☒ 388664
# Q 545*47  T 25615  ☒ 25415
# Q 181*72  T 13032  ☑ 13032
# Q 183*93  T 17019  ☒ 17099
# Q 772*730 T 563560 ☒ 567560
# Q 533*8   T 4264   ☑ 4264
# Q 432*163 T 70416  ☒ 70016
# Q 988*346 T 341848 ☒ 342048
# Q 292*2   T 584    ☑ 584
#
# --------------------------------------------------
# Iteration 65
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0645 - acc: 0.9792 - val_loss: 0.6454 - val_acc: 0.8533
# Q 862*144 T 124128 ☒ 123728
# Q 809*264 T 213576 ☒ 213776
# Q 934*573 T 535182 ☒ 535382
# Q 624*170 T 106080 ☑ 106080
# Q 462*78  T 36036  ☒ 36636
# Q 487*192 T 93504  ☒ 93304
# Q 785*541 T 424685 ☒ 424885
# Q 803*361 T 289883 ☒ 289483
# Q 555*106 T 58830  ☑ 58830
# Q 481*210 T 101010 ☑ 101010
#
# --------------------------------------------------
# Iteration 66
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0646 - acc: 0.9791 - val_loss: 0.6428 - val_acc: 0.8556
# Q 913*142 T 129646 ☒ 129446
# Q 899*412 T 370388 ☒ 370188
# Q 534*367 T 195978 ☒ 196178
# Q 825*735 T 606375 ☒ 606875
# Q 843*717 T 604431 ☑ 604431
# Q 689*582 T 400998 ☑ 400998
# Q 422*385 T 162470 ☒ 162070
# Q 846*732 T 619272 ☒ 618872
# Q 888*404 T 358752 ☒ 359152
# Q 608*366 T 222528 ☒ 222128
#
# --------------------------------------------------
# Iteration 67
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 174us/step - loss: 0.0653 - acc: 0.9790 - val_loss: 0.6532 - val_acc: 0.8552
# Q 626*479 T 299854 ☒ 309054
# Q 405*67  T 27135  ☒ 27335
# Q 785*25  T 19625  ☑ 19625
# Q 923*612 T 564876 ☒ 574676
# Q 552*8   T 4416   ☑ 4416
# Q 956*387 T 369972 ☒ 369372
# Q 735*307 T 225645 ☒ 225245
# Q 955*7   T 6685   ☑ 6685
# Q 853*151 T 128803 ☒ 127783
# Q 806*405 T 326430 ☒ 325430
#
# --------------------------------------------------
# Iteration 68
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0628 - acc: 0.9798 - val_loss: 0.6630 - val_acc: 0.8535
# Q 708*668 T 472944 ☒ 473944
# Q 269*13  T 3497   ☑ 3497
# Q 947*429 T 406263 ☒ 406163
# Q 730*45  T 32850  ☑ 32850
# Q 724*483 T 349692 ☒ 349092
# Q 589*333 T 196137 ☒ 196937
# Q 487*348 T 169476 ☒ 169076
# Q 660*161 T 106260 ☒ 107260
# Q 725*353 T 255925 ☑ 255925
# Q 701*685 T 480185 ☒ 479185
#
# --------------------------------------------------
# Iteration 69
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0602 - acc: 0.9808 - val_loss: 0.6650 - val_acc: 0.8543
# Q 218*51  T 11118  ☑ 11118
# Q 699*171 T 119529 ☒ 119329
# Q 177*76  T 13452  ☒ 13352
# Q 935*308 T 287980 ☑ 287980
# Q 630*7   T 4410   ☑ 4410
# Q 837*321 T 268677 ☒ 269677
# Q 769*749 T 575981 ☒ 576781
# Q 288*72  T 20736  ☒ 20936
# Q 860*328 T 282080 ☑ 282080
# Q 552*344 T 189888 ☒ 190688
#
# --------------------------------------------------
# Iteration 70
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.0625 - acc: 0.9802 - val_loss: 0.6646 - val_acc: 0.8548
# Q 501*36  T 18036  ☑ 18036
# Q 320*77  T 24640  ☑ 24640
# Q 627*619 T 388113 ☒ 398113
# Q 865*89  T 76985  ☑ 76985
# Q 995*722 T 718390 ☑ 718390
# Q 366*283 T 103578 ☑ 103578
# Q 806*681 T 548886 ☒ 548486
# Q 902*11  T 9922   ☑ 9922
# Q 476*213 T 101388 ☑ 101388
# Q 617*360 T 222120 ☑ 222120
#
# --------------------------------------------------
# Iteration 71
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0591 - acc: 0.9814 - val_loss: 0.6789 - val_acc: 0.8539
# Q 596*126 T 75096  ☒ 74296
# Q 263*45  T 11835  ☑ 11835
# Q 934*185 T 172790 ☑ 172790
# Q 256*128 T 32768  ☒ 32168
# Q 385*59  T 22715  ☑ 22715
# Q 776*506 T 392656 ☒ 393056
# Q 658*87  T 57246  ☒ 57846
# Q 881*564 T 496884 ☒ 496284
# Q 447*144 T 64368  ☒ 63768
# Q 559*55  T 30745  ☑ 30745
#
# --------------------------------------------------
# Iteration 72
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0607 - acc: 0.9809 - val_loss: 0.6726 - val_acc: 0.8547
# Q 839*71  T 59569  ☑ 59569
# Q 669*95  T 63555  ☒ 63255
# Q 847*593 T 502271 ☒ 501671
# Q 674*481 T 324194 ☒ 323794
# Q 829*422 T 349838 ☒ 349638
# Q 712*673 T 479176 ☑ 479176
# Q 865*640 T 553600 ☒ 558600
# Q 859*516 T 443244 ☒ 444044
# Q 433*66  T 28578  ☒ 28978
# Q 723*229 T 165567 ☒ 165267
#
# --------------------------------------------------
# Iteration 73
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.0559 - acc: 0.9825 - val_loss: 0.6823 - val_acc: 0.8545
# Q 554*333 T 184482 ☒ 184082
# Q 785*80  T 62800  ☑ 62800
# Q 756*329 T 248724 ☒ 249324
# Q 485*348 T 168780 ☒ 169780
# Q 922*602 T 555044 ☒ 554244
# Q 932*354 T 329928 ☒ 320728
# Q 628*235 T 147580 ☒ 147980
# Q 848*581 T 492688 ☑ 492688
# Q 845*251 T 212095 ☒ 211095
# Q 487*317 T 154379 ☒ 154679
#
# --------------------------------------------------
# Iteration 74
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0581 - acc: 0.9816 - val_loss: 0.6890 - val_acc: 0.8546
# Q 757*550 T 416350 ☒ 416850
# Q 932*202 T 188264 ☒ 188064
# Q 906*207 T 187542 ☒ 187942
# Q 962*36  T 34632  ☑ 34632
# Q 494*384 T 189696 ☒ 189496
# Q 922*175 T 161350 ☒ 160150
# Q 779*291 T 226689 ☒ 226889
# Q 722*459 T 331398 ☒ 330598
# Q 980*9   T 8820   ☑ 8820
# Q 991*981 T 972171 ☒ 972071
# accuracy =  37111 / 100000     37.111
#
# --------------------------------------------------
# Iteration 75
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0552 - acc: 0.9827 - val_loss: 0.6891 - val_acc: 0.8543
# Q 903*246 T 222138 ☒ 221938
# Q 649*65  T 42185  ☒ 42585
# Q 994*914 T 908516 ☒ 908576
# Q 985*649 T 639265 ☑ 639265
# Q 961*883 T 848563 ☑ 848563
# Q 503*283 T 142349 ☒ 142149
# Q 380*305 T 115900 ☑ 115900
# Q 628*106 T 66568  ☒ 66368
# Q 458*60  T 27480  ☑ 27480
# Q 955*101 T 96455  ☑ 96455
#
# --------------------------------------------------
# Iteration 76
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 175us/step - loss: 0.0548 - acc: 0.9827 - val_loss: 0.7070 - val_acc: 0.8533
# Q 903*886 T 800058 ☑ 800058
# Q 674*128 T 86272  ☒ 86872
# Q 853*329 T 280637 ☑ 280637
# Q 185*35  T 6475   ☒ 6575
# Q 663*92  T 60996  ☑ 60996
# Q 958*207 T 198306 ☑ 198306
# Q 706*227 T 160262 ☒ 159762
# Q 566*200 T 113200 ☑ 113200
# Q 511*44  T 22484  ☒ 22084
# Q 933*778 T 725874 ☒ 725674
#
# --------------------------------------------------
# Iteration 77
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0538 - acc: 0.9831 - val_loss: 0.7238 - val_acc: 0.8520
# Q 337*82  T 27634  ☒ 27434
# Q 480*2   T 960    ☑ 960
# Q 127*39  T 4953   ☒ 4153
# Q 590*173 T 102070 ☒ 101070
# Q 550*58  T 31900  ☑ 31900
# Q 361*86  T 31046  ☒ 30446
# Q 986*78  T 76908  ☑ 76908
# Q 373*311 T 116003 ☑ 116003
# Q 518*20  T 10360  ☑ 10360
# Q 683*154 T 105182 ☒ 104822
#
# --------------------------------------------------
# Iteration 78
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0546 - acc: 0.9827 - val_loss: 0.7007 - val_acc: 0.8547
# Q 576*511 T 294336 ☑ 294336
# Q 718*15  T 10770  ☑ 10770
# Q 712*488 T 347456 ☒ 346056
# Q 495*103 T 50985  ☒ 50385
# Q 364*351 T 127764 ☒ 128564
# Q 384*168 T 64512  ☒ 64912
# Q 801*553 T 442953 ☒ 443153
# Q 821*13  T 10673  ☑ 10673
# Q 568*10  T 5680   ☑ 5680
# Q 973*808 T 786184 ☒ 786384
#
# --------------------------------------------------
# Iteration 79
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0520 - acc: 0.9838 - val_loss: 0.7099 - val_acc: 0.8548
# Q 733*368 T 269744 ☒ 269344
# Q 485*293 T 142105 ☒ 141705
# Q 495*92  T 45540  ☒ 45740
# Q 526*288 T 151488 ☒ 151088
# Q 668*80  T 53440  ☑ 53440
# Q 560*276 T 154560 ☑ 154560
# Q 310*125 T 38750  ☑ 38750
# Q 794*438 T 347772 ☑ 347772
# Q 873*658 T 574434 ☒ 573834
# Q 935*512 T 478720 ☒ 478120
#
# --------------------------------------------------
# Iteration 80
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 50s 184us/step - loss: 0.0549 - acc: 0.9827 - val_loss: 0.7120 - val_acc: 0.8550
# Q 953*771 T 734763 ☒ 734163
# Q 186*167 T 31062  ☒ 31262
# Q 823*132 T 108636 ☒ 108936
# Q 880*44  T 38720  ☑ 38720
# Q 719*55  T 39545  ☑ 39545
# Q 696*611 T 425256 ☒ 425856
# Q 780*179 T 139620 ☑ 139620
# Q 780*442 T 344760 ☑ 344760
# Q 671*213 T 142923 ☒ 142723
# Q 525*470 T 246750 ☑ 246750
#
# --------------------------------------------------
# Iteration 81
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0505 - acc: 0.9842 - val_loss: 0.7248 - val_acc: 0.8544
# Q 698*71  T 49558  ☒ 49658
# Q 924*718 T 663432 ☒ 663832
# Q 972*962 T 935064 ☒ 935864
# Q 739*397 T 293383 ☒ 292383
# Q 258*86  T 22188  ☒ 22388
# Q 702*6   T 4212   ☑ 4212
# Q 750*556 T 417000 ☒ 419000
# Q 771*492 T 379332 ☑ 379332
# Q 888*181 T 160728 ☑ 160728
# Q 472*400 T 188800 ☑ 188800
#
# --------------------------------------------------
# Iteration 82
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 50s 185us/step - loss: 0.0510 - acc: 0.9841 - val_loss: 0.7194 - val_acc: 0.8550
# Q 457*53  T 24221  ☒ 24521
# Q 497*274 T 136178 ☒ 135778
# Q 949*757 T 718393 ☒ 719293
# Q 813*150 T 121950 ☑ 121950
# Q 605*64  T 38720  ☑ 38720
# Q 229*79  T 18091  ☒ 18391
# Q 790*178 T 140620 ☒ 130620
# Q 628*180 T 113040 ☑ 113040
# Q 259*126 T 32634  ☒ 33034
# Q 937*787 T 737419 ☒ 737019
#
# --------------------------------------------------
# Iteration 83
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0503 - acc: 0.9843 - val_loss: 0.7339 - val_acc: 0.8544
# Q 929*231 T 214599 ☒ 215399
# Q 897*144 T 129168 ☒ 129368
# Q 859*419 T 359921 ☒ 360321
# Q 358*32  T 11456  ☒ 11656
# Q 578*556 T 321368 ☒ 320768
# Q 854*753 T 643062 ☒ 642562
# Q 786*126 T 99036  ☒ 98636
# Q 762*223 T 169926 ☒ 179526
# Q 486*228 T 110808 ☒ 110208
# Q 775*220 T 170500 ☒ 160500
#
# --------------------------------------------------
# Iteration 84
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 182us/step - loss: 0.0492 - acc: 0.9846 - val_loss: 0.7319 - val_acc: 0.8547
# Q 205*37  T 7585   ☑ 7585
# Q 912*46  T 41952  ☑ 41952
# Q 972*118 T 114696 ☑ 114696
# Q 568*246 T 139728 ☒ 139128
# Q 931*477 T 444087 ☒ 443607
# Q 602*90  T 54180  ☑ 54180
# Q 696*207 T 144072 ☒ 143472
# Q 798*57  T 45486  ☒ 46486
# Q 880*229 T 201520 ☑ 201520
# Q 351*93  T 32643  ☒ 32943
#
# --------------------------------------------------
# Iteration 85
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 182us/step - loss: 0.0499 - acc: 0.9844 - val_loss: 0.7421 - val_acc: 0.8534
# Q 941*143 T 134563 ☒ 133763
# Q 926*354 T 327804 ☒ 327004
# Q 973*239 T 232547 ☒ 232147
# Q 744*43  T 31992  ☑ 31992
# Q 184*21  T 3864   ☑ 3864
# Q 975*613 T 597675 ☑ 597675
# Q 256*144 T 36864  ☒ 36464
# Q 690*215 T 148350 ☑ 148350
# Q 703*362 T 254486 ☒ 254686
# Q 961*705 T 677505 ☒ 676505
#
# --------------------------------------------------
# Iteration 86
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 183us/step - loss: 0.0507 - acc: 0.9842 - val_loss: 0.7389 - val_acc: 0.8546
# Q 885*383 T 338955 ☒ 339355
# Q 236*2   T 472    ☑ 472
# Q 854*370 T 315980 ☑ 315980
# Q 735*435 T 319725 ☑ 319725
# Q 970*670 T 649900 ☑ 649900
# Q 875*652 T 570500 ☑ 570500
# Q 798*323 T 257754 ☒ 258754
# Q 621*545 T 338445 ☒ 337945
# Q 689*440 T 303160 ☒ 397160
# Q 937*77  T 72149  ☑ 72149
#
# --------------------------------------------------
# Iteration 87
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 47s 176us/step - loss: 0.0490 - acc: 0.9848 - val_loss: 0.7322 - val_acc: 0.8558
# Q 842*12  T 10104  ☑ 10104
# Q 298*290 T 86420  ☑ 86420
# Q 928*752 T 697856 ☒ 697656
# Q 648*475 T 307800 ☒ 308400
# Q 715*184 T 131560 ☑ 131560
# Q 723*414 T 299322 ☒ 299522
# Q 696*207 T 144072 ☒ 143872
# Q 990*87  T 86130  ☑ 86130
# Q 362*333 T 120546 ☒ 119546
# Q 567*80  T 45360  ☑ 45360
#
# --------------------------------------------------
# Iteration 88
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 50s 184us/step - loss: 0.0465 - acc: 0.9857 - val_loss: 0.7483 - val_acc: 0.8544
# Q 636*551 T 350436 ☑ 350436
# Q 907*129 T 117003 ☒ 116603
# Q 501*480 T 240480 ☒ 230480
# Q 890*191 T 169990 ☒ 169190
# Q 674*453 T 305322 ☒ 305722
# Q 823*510 T 419730 ☑ 419730
# Q 176*138 T 24288  ☒ 24088
# Q 992*805 T 798560 ☒ 797760
# Q 998*964 T 962072 ☒ 962172
# Q 719*485 T 348715 ☒ 348115
#
# --------------------------------------------------
# Iteration 89
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0495 - acc: 0.9845 - val_loss: 0.7402 - val_acc: 0.8546
# Q 784*0   T 0      ☑ 0
# Q 960*755 T 724800 ☑ 724800
# Q 534*51  T 27234  ☒ 27294
# Q 927*15  T 13905  ☒ 13805
# Q 868*842 T 730856 ☒ 730456
# Q 989*9   T 8901   ☑ 8901
# Q 929*188 T 174652 ☑ 174652
# Q 996*376 T 374496 ☒ 374696
# Q 575*127 T 73025  ☒ 73625
# Q 759*480 T 364320 ☑ 364320
#
# --------------------------------------------------
# Iteration 90
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 180us/step - loss: 0.0478 - acc: 0.9852 - val_loss: 0.7498 - val_acc: 0.8543
# Q 689*223 T 153647 ☒ 154447
# Q 374*286 T 106964 ☒ 107364
# Q 871*808 T 703768 ☒ 704368
# Q 388*326 T 126488 ☒ 127488
# Q 726*246 T 178596 ☒ 179796
# Q 550*216 T 118800 ☑ 118800
# Q 767*265 T 203255 ☒ 202955
# Q 657*177 T 116289 ☒ 116089
# Q 326*21  T 6846   ☑ 6846
# Q 999*911 T 910089 ☑ 910089
#
# --------------------------------------------------
# Iteration 91
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0466 - acc: 0.9856 - val_loss: 0.7504 - val_acc: 0.8551
# Q 496*321 T 159216 ☒ 159616
# Q 632*289 T 182648 ☒ 182248
# Q 153*42  T 6426   ☑ 6426
# Q 988*976 T 964288 ☒ 964488
# Q 443*412 T 182516 ☒ 182116
# Q 543*268 T 145524 ☒ 144924
# Q 996*884 T 880464 ☑ 880464
# Q 244*41  T 10004  ☒ 9864
# Q 891*548 T 488268 ☑ 488268
# Q 582*243 T 141426 ☒ 141226
#
# --------------------------------------------------
# Iteration 92
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 180us/step - loss: 0.0472 - acc: 0.9853 - val_loss: 0.7597 - val_acc: 0.8545
# Q 973*187 T 181951 ☒ 182751
# Q 794*565 T 448610 ☒ 449610
# Q 541*322 T 174202 ☒ 174002
# Q 940*870 T 817800 ☑ 817800
# Q 147*144 T 21168  ☒ 20368
# Q 878*425 T 373150 ☑ 373150
# Q 508*108 T 54864  ☒ 55864
# Q 741*110 T 81510  ☑ 81510
# Q 577*53  T 30581  ☑ 30581
# Q 823*241 T 198343 ☒ 198443
#
# --------------------------------------------------
# Iteration 93
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0468 - acc: 0.9854 - val_loss: 0.7691 - val_acc: 0.8535
# Q 800*247 T 197600 ☑ 197600
# Q 983*929 T 913207 ☒ 912007
# Q 671*42  T 28182  ☑ 28182
# Q 808*548 T 442784 ☒ 443784
# Q 734*216 T 158544 ☒ 158944
# Q 582*139 T 80898  ☒ 80198
# Q 790*672 T 530880 ☒ 531880
# Q 565*64  T 36160  ☒ 36360
# Q 754*62  T 46748  ☑ 46748
# Q 570*264 T 150480 ☒ 149880
#
# --------------------------------------------------
# Iteration 94
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 183us/step - loss: 0.0450 - acc: 0.9860 - val_loss: 0.7633 - val_acc: 0.8545
# Q 803*72  T 57816  ☑ 57816
# Q 592*364 T 215488 ☒ 215888
# Q 918*565 T 518670 ☒ 519270
# Q 846*335 T 283410 ☒ 282010
# Q 627*146 T 91542  ☒ 91842
# Q 634*408 T 258672 ☒ 258272
# Q 639*467 T 298413 ☒ 297413
# Q 529*8   T 4232   ☑ 4232
# Q 147*144 T 21168  ☒ 20768
# Q 769*736 T 565984 ☒ 556784
#
# --------------------------------------------------
# Iteration 95
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 177us/step - loss: 0.0477 - acc: 0.9851 - val_loss: 0.7575 - val_acc: 0.8560
# Q 658*512 T 336896 ☒ 337696
# Q 652*186 T 121272 ☒ 121872
# Q 789*276 T 217764 ☑ 217764
# Q 734*189 T 138726 ☒ 139326
# Q 332*155 T 51460  ☒ 51360
# Q 978*252 T 246456 ☑ 246456
# Q 909*323 T 293607 ☑ 293607
# Q 785*595 T 467075 ☒ 466875
# Q 804*783 T 629532 ☒ 629732
# Q 809*760 T 614840 ☑ 614840
#
# --------------------------------------------------
# Iteration 96
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 183us/step - loss: 0.0428 - acc: 0.9868 - val_loss: 0.7765 - val_acc: 0.8541
# Q 203*170 T 34510  ☑ 34510
# Q 824*740 T 609760 ☑ 609760
# Q 673*20  T 13460  ☑ 13460
# Q 370*164 T 60680  ☒ 60080
# Q 861*546 T 470106 ☒ 470906
# Q 426*12  T 5112   ☒ 5172
# Q 702*665 T 466830 ☒ 466230
# Q 889*502 T 446278 ☒ 446478
# Q 657*550 T 361350 ☑ 361350
# Q 171*159 T 27189  ☒ 26189
#
# --------------------------------------------------
# Iteration 97
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 49s 181us/step - loss: 0.0455 - acc: 0.9858 - val_loss: 0.7704 - val_acc: 0.8544
# Q 320*175 T 56000  ☒ 55000
# Q 941*371 T 349111 ☒ 348511
# Q 257*170 T 43690  ☒ 42690
# Q 282*132 T 37224  ☑ 37224
# Q 726*171 T 124146 ☒ 124546
# Q 236*224 T 52864  ☒ 53264
# Q 628*143 T 89804  ☒ 89204
# Q 690*597 T 411930 ☒ 412930
# Q 867*430 T 372810 ☑ 372810
# Q 885*343 T 303555 ☑ 303555
#
# --------------------------------------------------
# Iteration 98
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 179us/step - loss: 0.0429 - acc: 0.9866 - val_loss: 0.7786 - val_acc: 0.8539
# Q 959*5   T 4795   ☒ 4895
# Q 623*36  T 22428  ☑ 22428
# Q 640*10  T 6400   ☑ 6400
# Q 610*437 T 266570 ☑ 266570
# Q 633*239 T 151287 ☒ 150887
# Q 122*79  T 9638   ☒ 9538
# Q 818*98  T 80164  ☒ 79164
# Q 867*270 T 234090 ☒ 233090
# Q 972*787 T 764964 ☒ 765964
# Q 918*293 T 268974 ☒ 268374
#
# --------------------------------------------------
# Iteration 99
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/1
# 270000/270000 [==============================] - 48s 178us/step - loss: 0.0462 - acc: 0.9856 - val_loss: 0.7695 - val_acc: 0.8551
# Q 200*179 T 35800  ☑ 35800
# Q 411*56  T 23016  ☑ 23016
# Q 764*457 T 349148 ☒ 349748
# Q 882*645 T 568890 ☒ 568090
# Q 912*424 T 386688 ☒ 386488
# Q 985*790 T 778150 ☑ 778150
# Q 824*418 T 344432 ☒ 345632
# Q 767*2   T 1534   ☑ 1534
# Q 385*220 T 84700  ☑ 84700
# Q 388*78  T 30264  ☒ 30664
# accuracy =  37107 / 100000     37.107

# %% [markdown]
# # Testing

# %%
print("MSG : Prediction")
#####################################################
## Try to test and evaluate your model ##############
## ex. test_x = ["555+175", "860+7  ", "340+29 "]
## ex. test_y = ["730 ", "867 ", "369 "] 
#####################################################

acc = 0.0
pre_y = model.predict(test_x)
pre_y = np.argmax(pre_y,axis = 2)
for i in range(test_x.shape[0]):
    rowx, rowy = test_x, test_y
    q = ctable.decode(rowx[i])
    correct = ctable.decode(rowy[i])
    guess = ctable.decode(pre_y[i], calc_argmax=False)
    if i < 10:
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
    if correct == guess:
        acc = acc + 1.0
        if i < 10:
            print(colors.ok + '☑' + colors.close, end=' ')
    else:
        if i < 10:
            print(colors.fail + '☒' + colors.close, end=' ')
    if i < 10:
        print(guess)
print('accuracy = ',int(acc), "/", test_x.shape[0], "   ", (acc*100.0/test_x.shape[0]) )
# Out:
# MSG : Prediction
# Q 982*570 T 559740 ☑ 559740
# Q 660*90  T 59400  ☑ 59400
# Q 780*296 T 230880 ☑ 230880
# Q 740*51  T 37740  ☑ 37740
# Q 608*544 T 330752 ☒ 331752
# Q 568*489 T 277752 ☒ 278152
# Q 836*330 T 275880 ☑ 275880
# Q 678*282 T 191196 ☒ 190596
# Q 838*667 T 558946 ☒ 558546
# Q 768*629 T 483072 ☒ 483672
# accuracy =  37107 / 100000     37.107
